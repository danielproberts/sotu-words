# %%
## Include Statements

import matplotlib.pyplot as plt
import pandas as pd
import sqlite3
import os
import re

# %%
# Build CSV File

f = open("sotuwords.csv", "w+")
f.write("name,date,countWar,countPeace,countGod,countProvidence,countHeaven,countTotal\n")
    
for filename in os.listdir(os.getcwd() + "/state-of-the-union-address-texts"):
    name = filename.split("[")
    name = name[0]
    name = name[:-1]
    date = filename[-10:-5]
    
    filepath = os.getcwd() + "/state-of-the-union-address-texts/" + filename
    
    reWar = "[\s,.]war[\s,.'s][\ss]?"
    rePeace = "[\s,.]peace[\s,.'ful']?"
    reGod = "[\s,.]god[\s,.'s][\ss]?" #[\s,.''s']"
    reProvidence = "[\s,.]providence[\s,.]"
    reHeaven = "[\s,.]heaven[\s,.]"
    reTotal = "\w+"

    file  = open(filepath, 'r', encoding = "ISO-8859-1").read()
    countWar = len(re.findall(reWar, file, re.IGNORECASE))
    countPeace = len(re.findall(rePeace, file, re.IGNORECASE))
    countGod = len(re.findall(reGod, file, re.IGNORECASE))
    countProvidence = len(re.findall(reProvidence, file, re.IGNORECASE))
    countHeaven = len(re.findall(reHeaven, file, re.IGNORECASE))
    countTotal = len(re.findall(reTotal, file, re.IGNORECASE))
    
    f.write(name + ",")
    f.write(date + ",")
    f.write(str(countWar) + ",")
    f.write(str(countPeace) + ",")
    f.write(str(countGod) + ",")
    f.write(str(countProvidence) + ",")
    f.write(str(countHeaven) + ",")
    f.write(str(countTotal) + "\n")

# %%
## Create Dataframe from File

data = pd.read_csv("sotuwords.csv", index_col=1)
data = data.sort_index()
print(data)
# Out:
#                     name  countWar  countPeace  countGod  countProvidence  \
# date
# 1790   George Washington         3           1         0                0
# 1791   George Washington         1           4         0                0
# 1792   George Washington         1           5         0                1
# 1793   George Washington         4           6         0                0
# 1794   George Washington         1           4         0                0
# 1795   George Washington         4           4         0                0
# 1796   George Washington        12           5         0                0
# 1797          John Adams         4           4         0                2
# 1798          John Adams         5           5         0                2
# 1799          John Adams         3           0         0                1
# 1800          John Adams         1           0         0                0
# 1801    Thomas Jefferson         8           9         0                0
# 1802    Thomas Jefferson         3           5         0                1
# 1803    Thomas Jefferson         4           8         0                1
# 1804    Thomas Jefferson         7           7         0                0
# 1805    Thomas Jefferson         5          10         0                1
# 1806    Thomas Jefferson         6           7         0                0
# 1807    Thomas Jefferson         2          12         0                0
# 1808    Thomas Jefferson         1           2         0                0
# 1809       James Madison         3           2         0                1
# 1810       James Madison         5           1         0                1
# 1811       James Madison         3           2         0                0
# 1812       James Madison        20           5         0                0
# 1813       James Madison        29           5         0                0
# 1814       James Madison        10           4         0                1
# 1815       James Madison         9          13         0                1
# 1816       James Madison         9           7         0                1
# 1817        James Monroe         6           0         0                0
# 1818        James Monroe        10           3         0                1
# 1819        James Monroe         5           2         0                0
# ...                  ...       ...         ...       ...              ...
# 1990         George Bush         1           6         4                0
# 1991         George Bush        10          11         1                0
# 1992         George Bush         6           4         3                0
# 1993  William J. Clinton         0           3         1                0
# 1994  William J. Clinton         1           5         3                0
# 1995  William J. Clinton         5           9         1                0
# 1996  William J. Clinton         6          11         2                0
# 1997  William J. Clinton         9          10         2                0
# 1998  William J. Clinton         3           7         3                0
# 1999  William J. Clinton         5          12         1                0
# 2000  William J. Clinton         4           9         3                0
# 2001      George W. Bush         1           6         1                0
# 2002      George W. Bush        10           5         2                0
# 2003      George W. Bush        11          10         3                1
# 2004      George W. Bush        12           5         3                0
# 2005      George W. Bush         5          12         1                1
# 2006      George W. Bush         2           8         1                0
# 2007      George W. Bush        10           3         2                0
# 2008      George W. Bush         3           9         1                0
# 2009        Barack Obama         5           1         2                0
# 2010        Barack Obama         7           2         2                0
# 2011        Barack Obama         4           1         2                0
# 2012        Barack Obama         6           1         2                0
# 2013        Barack Obama         3           1         2                0
# 2014        Barack Obama         7           5         2                0
# 2015        Barack Obama         5           1         2                0
# 2016        Barack Obama         8           2         2                0
# 2017     Donald J. Trump         6           4         3                0
# 2018     Donald J. Trump         2           0         4                0
# 2019     Donald J. Trump         9           3         5                0
#
#       countHeaven  countTotal
# date
# 1790            0        1411
# 1791            0        2314
# 1792            0        2102
# 1793            0        1971
# 1794            1        2920
# 1795            1        1986
# 1796            0        2879
# 1797            0        2060
# 1798            0        2218
# 1799            0        1505
# 1800            0        1374
# 1801            0        3228
# 1802            0        2205
# 1803            0        2273
# 1804            0        2103
# 1805            0        2934
# 1806            0        2870
# 1807            0        2397
# 1808            1        2683
# 1809            0        1832
# 1810            0        2451
# 1811            1        2275
# 1812            0        3251
# 1813            1        3266
# 1814            0        2116
# 1815            0        3148
# 1816            0        3369
# 1817            0        4434
# 1818            0        4378
# 1819            0        4711
# ...           ...         ...
# 1990            0        3879
# 1991            0        4020
# 1992            0        5224
# 1993            0        7127
# 1994            0        7547
# 1995            0        9403
# 1996            0        6438
# 1997            0        6854
# 1998            0        7438
# 1999            0        7628
# 2000            0        9275
# 2001            0        4449
# 2002            1        3876
# 2003            0        5450
# 2004            0        5242
# 2005            0        5114
# 2006            0        5367
# 2007            0        5649
# 2008            0        5794
# 2009            0        6199
# 2010            0        7486
# 2011            0        7113
# 2012            0        7270
# 2013            0        7013
# 2014            0        7265
# 2015            0        7004
# 2016            0        6279
# 2017            0        5089
# 2018            0        5985
# 2019            1        5799
#
# [224 rows x 7 columns]

# %%
## Create Database from Data Frame

conn = sqlite3.connect("sotuwords.db")
data.to_sql("sotuwords", conn, if_exists="replace")

# %%
# SQL Queries

sqlAll = "SELECT date, name, countTotal FROM sotuwords"
sqlColdWar = "SELECT date, name, countWar, countPeace FROM sotuwords WHERE date >= 1947"

sqlWarOverPeace = "SELECT date FROM sotuwords WHERE countWar > countPeace"
sqlPeaceOverWar = "SELECT date FROM sotuwords WHERE countPeace > countWar"
sqlWarPeace = "SELECT date FROM sotuWords WHERE countWar == countPeace"

dfColdWar = pd.read_sql(sqlColdWar, conn)
dfAll = pd.read_sql(sqlAll, conn)

countWarOverPeace = len(pd.read_sql(sqlWarOverPeace, conn))
countPeaceOverWar = len(pd.read_sql(sqlPeaceOverWar, conn))
countWarPeace = len(pd.read_sql(sqlWarPeace, conn))

# %%
## Print Data Frame for Cold War Comparisons

print(dfColdWar)
# Out:
#     date                  name  countWar  countPeace
# 0   1947       Harry S. Truman        20          21
# 1   1948       Harry S. Truman        14          14
# 2   1949       Harry S. Truman         0           5
# 3   1950       Harry S. Truman         4          17
# 4   1951       Harry S. Truman         8           9
# 5   1952       Harry S. Truman        12          24
# 6   1953       Harry S. Truman        45          18
# 7   1954  Dwight D. Eisenhower         4          13
# 8   1955  Dwight D. Eisenhower         3          21
# 9   1956  Dwight D. Eisenhower         8          23
# 10  1957  Dwight D. Eisenhower         4          13
# 11  1958  Dwight D. Eisenhower         8          29
# 12  1959  Dwight D. Eisenhower         6           8
# 13  1960  Dwight D. Eisenhower         7          21
# 14  1961  Dwight D. Eisenhower         6          19
# 15  1962       John F. Kennedy         6          16
# 16  1963       John F. Kennedy         6          17
# 17  1964     Lyndon B. Johnson         7           6
# 18  1965     Lyndon B. Johnson         4           8
# 19  1966     Lyndon B. Johnson        15          19
# 20  1967     Lyndon B. Johnson        17          10
# 21  1968     Lyndon B. Johnson         6          10
# 22  1969     Lyndon B. Johnson         3          11
# 23  1970         Richard Nixon        15          17
# 24  1971         Richard Nixon         4           8
# 25  1972         Richard Nixon        21          20
# 26  1974         Richard Nixon         7          22
# 27  1975        Gerald R. Ford         2           4
# 28  1976        Gerald R. Ford         6           3
# 29  1977        Gerald R. Ford         9          16
# ..   ...                   ...       ...         ...
# 42  1990           George Bush         1           6
# 43  1991           George Bush        10          11
# 44  1992           George Bush         6           4
# 45  1993    William J. Clinton         0           3
# 46  1994    William J. Clinton         1           5
# 47  1995    William J. Clinton         5           9
# 48  1996    William J. Clinton         6          11
# 49  1997    William J. Clinton         9          10
# 50  1998    William J. Clinton         3           7
# 51  1999    William J. Clinton         5          12
# 52  2000    William J. Clinton         4           9
# 53  2001        George W. Bush         1           6
# 54  2002        George W. Bush        10           5
# 55  2003        George W. Bush        11          10
# 56  2004        George W. Bush        12           5
# 57  2005        George W. Bush         5          12
# 58  2006        George W. Bush         2           8
# 59  2007        George W. Bush        10           3
# 60  2008        George W. Bush         3           9
# 61  2009          Barack Obama         5           1
# 62  2010          Barack Obama         7           2
# 63  2011          Barack Obama         4           1
# 64  2012          Barack Obama         6           1
# 65  2013          Barack Obama         3           1
# 66  2014          Barack Obama         7           5
# 67  2015          Barack Obama         5           1
# 68  2016          Barack Obama         8           2
# 69  2017       Donald J. Trump         6           4
# 70  2018       Donald J. Trump         2           0
# 71  2019       Donald J. Trump         9           3
#
# [72 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
plt.plot(dfColdWar.date, dfColdWar.countWar, label="War", color="red")
plt.plot(dfColdWar.date, dfColdWar.countPeace, label="Peace", color="green")
plt.title('Uses of the Words "War" and "Peace" (1947 - Present)')
plt.xlabel('Year')
plt.ylabel('Word Count')
plt.legend(loc='upper right')
plt.show()

# %%
## Print Data Frame for Total Word Count for all SOTU Addresses

print(dfAll)
# Out:
#      date                name  countTotal
# 0    1790   George Washington        1411
# 1    1791   George Washington        2314
# 2    1792   George Washington        2102
# 3    1793   George Washington        1971
# 4    1794   George Washington        2920
# 5    1795   George Washington        1986
# 6    1796   George Washington        2879
# 7    1797          John Adams        2060
# 8    1798          John Adams        2218
# 9    1799          John Adams        1505
# 10   1800          John Adams        1374
# 11   1801    Thomas Jefferson        3228
# 12   1802    Thomas Jefferson        2205
# 13   1803    Thomas Jefferson        2273
# 14   1804    Thomas Jefferson        2103
# 15   1805    Thomas Jefferson        2934
# 16   1806    Thomas Jefferson        2870
# 17   1807    Thomas Jefferson        2397
# 18   1808    Thomas Jefferson        2683
# 19   1809       James Madison        1832
# 20   1810       James Madison        2451
# 21   1811       James Madison        2275
# 22   1812       James Madison        3251
# 23   1813       James Madison        3266
# 24   1814       James Madison        2116
# 25   1815       James Madison        3148
# 26   1816       James Madison        3369
# 27   1817        James Monroe        4434
# 28   1818        James Monroe        4378
# 29   1819        James Monroe        4711
# ..    ...                 ...         ...
# 194  1990         George Bush        3879
# 195  1991         George Bush        4020
# 196  1992         George Bush        5224
# 197  1993  William J. Clinton        7127
# 198  1994  William J. Clinton        7547
# 199  1995  William J. Clinton        9403
# 200  1996  William J. Clinton        6438
# 201  1997  William J. Clinton        6854
# 202  1998  William J. Clinton        7438
# 203  1999  William J. Clinton        7628
# 204  2000  William J. Clinton        9275
# 205  2001      George W. Bush        4449
# 206  2002      George W. Bush        3876
# 207  2003      George W. Bush        5450
# 208  2004      George W. Bush        5242
# 209  2005      George W. Bush        5114
# 210  2006      George W. Bush        5367
# 211  2007      George W. Bush        5649
# 212  2008      George W. Bush        5794
# 213  2009        Barack Obama        6199
# 214  2010        Barack Obama        7486
# 215  2011        Barack Obama        7113
# 216  2012        Barack Obama        7270
# 217  2013        Barack Obama        7013
# 218  2014        Barack Obama        7265
# 219  2015        Barack Obama        7004
# 220  2016        Barack Obama        6279
# 221  2017     Donald J. Trump        5089
# 222  2018     Donald J. Trump        5985
# 223  2019     Donald J. Trump        5799
#
# [224 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
plt.plot(dfAll.date, dfAll.countTotal, label="Total Words", color="blue")
plt.xlabel('Year')
plt.ylabel('Total Words')
plt.legend(loc='upper right')
plt.title('Total Number of Words in SOTU Addresses (1790 - 2019)')
plt.show()

# %%
#print(countWarOverPeace)
#print(countPeaceOverWar)
#print(countWarPeace)

plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
plt.pie([countWarOverPeace, countPeaceOverWar, countWarPeace], labels=["War > Peace: " + str(countWarOverPeace) + " Occurrences", "Peace > War: " + str(countPeaceOverWar) + " Occurrences", "Equal: " + str(countWarPeace) + " Occurrences"])
plt.title('Number of Times "War" or "Peace" Is Used The Greatest Number of Times')
plt.show()
